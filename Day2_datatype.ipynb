# %%
#integer
print(4)
# Out:
# 4

# %%
print(1e309)
# Out:
# inf

# %%
print(1e308)
# Out:
# 1e+308

# %%
#boolean
print(True)
# Out:
# True

# %%
#complex
print(4+5J)
# Out:
# (4+5j)

# %%
#string
print("Mumbai")
# Out:
# Mumbai

# %%
print('Mumbai')
# Out:
# Mumbai

# %%
#list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({"name":"sagar","Age":30})
# Out:
# {'name': 'sagar', 'Age': 30}
