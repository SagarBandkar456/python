# %%
l=[]

# %%
l=[1,2,4,5]
l
# Out:
# [1, 2, 4, 5]

# %%
l=[1,2,4,5,'string']
l
# Out:
# [1, 2, 4, 5, 'string']

# %%
l=[1,2,3,[4,5]]
l[-1][2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 l=[1,2,3,[4,5]]
# ----> 2 l[-1][2]
#
# IndexError: list index out of range

# %%
l4=list("test")
l4
# Out:
# ['t', 'e', 's', 't']

# %%
l4[0]
# Out:
# 't'

# %%
l=[1,2,3,4,5]
l[1:3]=[200,300]
l
# Out:
# [1, 200, 300, 4, 5]

# %%
l=[1,2,3,4,5]
l.extend([500,600])
l.insert(3,1000)
l
# Out:
# [1, 2, 3, 1000, 4, 5, 500, 600]

# %%
l=[1,2,3,4,5]
del l[0]
l.remove(4)
l.pop()
l.pop()
l.clear()
l
# Out:
# []

# %%
l=[1,2,3,4,5]
m=[6,7,8]
l+m
for l in l:
    print(l)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l=[1,2,3,4,5]
len(l)
min(l)
max(l)
l4=sorted(l,reverse=True)
l.sort()
l
# Out:
# [1, 2, 3, 4, 5]
