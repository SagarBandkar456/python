# %%
email=input("Enter username:-")
pwd=input("Enter password:-")

if email=='sagar' and pwd=='sagar':
    print("login successful")
elif email =='sagar' and pwd!='sagar':
    print("incorrect password")
else:
    print("Auth error")
# Out:
# Enter username:- sagar
# Enter password:- 344
# incorrect password
