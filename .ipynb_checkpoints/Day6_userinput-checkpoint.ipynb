# %%
input()
# Out:
#  56
# '56'

# %%
input("Enter username")
# Out:
# Enter username sagarbndkr@gmail.com
# 'sagarbndkr@gmail.com'

# %%
first_num=input("enter the first no")
second_num=input("enter the second no")
# Out:
# enter the first no 10
# enter the second no 20

# %%
result=first_num+second_num

# %%
print(result)
# Out:
# 1020

# %%
# type conversion
# implict
# explict

# %%
4+5.5
# Out:
# 9.5

# %%
5+6+7j
# Out:
# (11+7j)

# %%
#explict

# %%
#int
int(4.5)
# Out:
# 4

# %%
result=int(first_num)+int(second_num)

# %%
print(result)
# Out:
# 30

# %%
first_num=input("enter the first no")
second_num=input("enter the second no")
result=int(first_num)+int(second_num)
print(result)
# Out:
# enter the first no 10
# enter the second no 50
# 60

# %%
first_num=int(input("enter the first no"))
second_num=int(input("enter the second no"))
result=first_num+second_num
print(result)
# Out:
# enter the first no 50
# enter the second no 70
# 120
