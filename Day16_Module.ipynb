# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _tokenize           heapq               quopri
# __future__          _tracemalloc        hmac                random
# __hello__           _types              html                re
# __phello__          _typing             http                referencing
# _abc                _uuid               httpcore            reprlib
# _aix_support        _warnings           httpx               requests
# _android_support    _weakref            idlelib             rfc3339_validator
# _apple_support      _weakrefset         idna                rfc3986_validator
# _argon2_cffi_bindings _winapi             imaplib             rfc3987_syntax
# _ast                _wmi                importlib           rlcompleter
# _ast_unparse        _yaml               inspect             rpds
# _asyncio            _zoneinfo           io                  runpy
# ...

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(6.3)
# Out:
# 7

# %%
import random

# %%
random.randint(1,100)
# Out:
# 89

# %%
a=[1,2,3,4,5,6]
random.shuffle(a)
print(a)
# Out:
# [3, 5, 4, 1, 6, 2]

# %%
import time

# %%
time.time()
# Out:
# 1785725620.7617385

# %%
time.ctime()
# Out:
# 'Mon Aug  3 08:23:51 2026'

# %%
print('Hello')
time.sleep(1)
print('World')
# Out:
# Hello
# World

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\Project\\Python'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Day10_loops.ipynb',
#  'Day11_guessingNo.ipynb',
#  'Day12_forloop.ipynb',
#  'Day13_nestedloop.ipynb',
#  'Day14_break_continue.ipynb',
#  'Day15_builtinfunction&module.ipynb',
#  'Day16_Module.ipynb',
#  'Day1_print.ipynb',
#  'Day2_datatype.ipynb',
#  'Day3_comments.ipynb',
#  'Day4_variable.ipynb',
#  'Day5_keyword.ipynb',
#  'Day6_userinput.ipynb',
#  'Day7_literals.ipynb',
#  'Day8_operator.ipynb',
#  'Day9_ifelse.ipynb']
