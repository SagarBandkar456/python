# %%
c="kolkata"
len(c)
max(c)
min(c)
sorted(c)
sorted(c, reverse=True)
# Out:
# ['t', 'o', 'l', 'k', 'k', 'a', 'a']

# %%
c.capitalize()
"it is raining today".title()
c.upper()
c.lower()
'kolKATA'.swapcase()
# Out:
# 'KOLkata'

# %%
'it is raining'.count("i")
# Out:
# 4

# %%
'it is raining'.find("r")
'it is raining'.index("r")
# Out:
# 6

# %%
"it is raining".endswith('ing')
"it is raining".startswith('it')
# Out:
# True

# %%
"Hello my name is {} I am {}".format("Sagar",32)
# Out:
# 'Hello my name is Sagar I am 32'

# %%
"FLAT20".isalnum()
# Out:
# True

# %%
"Flat".isalpha()
# Out:
# True

# %%
'20'.isdigit()
# Out:
# True

# %%
'Hello_world'.isidentifier()
# Out:
# True

# %%
"who is the prime minisiter of india".split()
#"who is the prime minisiter of india".split('prime')
# Out:
# ['who', 'is', 'the', 'prime', 'minisiter', 'of', 'india']

# %%
"-".join(['who', 'is', 'the', 'prime', 'minisiter', 'of', 'india'])
# Out:
# 'who-is-the-prime-minisiter-of-india'

# %%
"Hi my name is sagar".replace("sagar","bbb")
# Out:
# 'Hi my name is bbb'

# %%
name="   sagar"
name.strip()
# Out:
# 'sagar'
