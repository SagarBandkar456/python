# %%
#creating 
c='Hello1'
print(c)

c="Hello1"
print(c)

c="""Hello1"""
print(c)

c=str("Hello")
print(c)
# Out:
# Hello1
# Hello1
# Hello1
# Hello

# %%
#concept of indexing
c='hello'
print(c[0])
# Out:
# h

# %%
# types of indexing
# positive indexing
# negative indexing

print(c[-1])
print(c[-2])
print(c[-3])
print(len(c))
# Out:
# o
# l
# l
# 5

# %%
# slicing
c="Hello World"
print(c)
# Out:
# Hello World

# %%
print(c[0:5])
print(c[2:])
print(c[:4])
print(c[:])
print(c[2:6:2]) #skip 
print(c[-5:-1:2]) #skip 
print(c[::-1]) #skip
# Out:
# Hello
# llo World
# Hell
# Hello World
# lo
# Wr
# dlroW olleH

# %%
#Ending and Deleting in strings
c="Hello"
print(c)
# Out:
# Hello

# %%
c[0]='x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 c[0]='x'
#
# TypeError: 'str' object does not support item assignment

# %%
c
# Out:
# 'Hello'

# %%
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
c="hello"

# %%
c
# Out:
# 'hello'

# %%
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
#operation on string
"Hello" +" "+ "World"
# Out:
# 'Hello World'

# %%
print("*"*50)
# Out:
# **************************************************

# %%
"Hello"=="world"
# Out:
# False

# %%
"Hello"!="world"
# Out:
# True

# %%
"Mumbai">"Pune" #lexigraphically
# Out:
# False

# %%
"Goa"<"Mumbai"
# Out:
# True

# %%
"hello" and "world"
# Out:
# 'world'

# %%
"" and "world"
# Out:
# ''

# %%
"" or "world"
# Out:
# 'world'

# %%
not "world"
# Out:
# False

# %%
c="hello world"
for i in c[2:7]:
    print(i)
# Out:
# l
# l
# o
#
# w

# %%
c
# Out:
# 'hello world'

# %%
'h' in c
# Out:
# True

# %%
'H' in c
# Out:
# False

# %%
'H' not in c
# Out:
# True
