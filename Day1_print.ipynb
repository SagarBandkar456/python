# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World", sep ="/")
# Out:
# Hello World

# %%
print("Hello World", sep ="/")
# Out:
# Hello World

# %%
print("Hello World", sep ='/')
# Out:
# Hello World

# %%
print("Hello World","india","Russia")
# Out:
# Hello World india Russia

# %%
print("india", 10+5)
# Out:
# india 15

# %%
print(10+5,"india")
# Out:
# 15 india

# %%
print("Hello","World","india","Russia",sep='/')
# Out:
# Hello/World/india/Russia

# %%
print("Hello World","india","Russia",sep='/')
# Out:
# Hello World/india/Russia

# %%
print("Hello World","india","Russia",end='/n')
# Out:
# Hello World india Russia/n

# %%
print("Hello World","india","Russia",end='\n')
# Out:
# Hello World india Russia

# %%
print("Hello"end='\n')
# Out:
#   Cell In[12], line 1
#     print("Hello"end='\n')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Hello",end='\n')
print("world")
# Out:
# Hello
# world

# %%
print("Hello",end=' ')
print("world")
# Out:
# Hello world
