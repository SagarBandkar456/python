# %%
x=5
y=2

print(x+y)
# Out:
# 7

# %%
print(x-y)
print(x*y)
print(x**y) #pow
print(x//y) #int div
# Out:
# 3
# 10
# 25
# 2

# %%
x=5
y=2
print(x>y)
print(x<y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# False
# True

# %%
x=5
y=2

# %%
x=True
y=False

print(x or y)
# Out:
# True
