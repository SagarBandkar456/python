# %%
a=0b1010 #binary
b=100 #decimal
c=0o310 #octal
d=0x12c #hexadeciaml

#float
float_1=10.5
float_2=1.5e2
float_3=1.5e-3

#complex
x=3.14J

print(a,b,c,d)
print(float_1,float_2,float_3)
print(x,x.imag,x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
#2. String literals

# %%
name="sagar"
name1='sagar'
#unicode unicode=u"\U001f40"
print(name,name1)
# Out:
# sagar sagar

# %%
# booleaan

# %%
a=True+1

# %%
b=False+10

# %%
print(a,b)
# Out:
# 2 10

# %%
#special

# %%
a=None
print(a)
# Out:
# None

# %%
#declare variable
k=None
