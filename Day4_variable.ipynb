# %%
# variable
name='sagar'
print(name)
# Out:
# sagar

# %% [markdown]
# name='gggg'

# %%
print(name)
# Out:
# sagar

# %%
#Dynamic typing - python language
#static typing- other language
#no vaiable declaration

# %%
name=4

# %%
print(name)
# Out:
# 4

# %%
#Dynamic binding

# %%
#static binding

# %%
# special syntax

# %%
a=5;b=6;c=7
print(a,b,c)
# Out:
# 5 6 7

# %%
a,b,c=4,5,6
print(a,b,c)
# Out:
# 4 5 6
